# %% [markdown]
# # Monte Carlo Simulations
# ### Import the necessary packages

# %%
##########################################################################################################################
import os
import pyreadr
import csv
import time
import numpy as np
import pandas as pd
import scipy.sparse as sp
from scipy.linalg import solve
from scipy.optimize import minimize
import matplotlib.pyplot as plt 
import itertools
import concurrent.futures
import matplotlib.colors as mcolors
from memory_profiler import profile
from concurrent.futures import ProcessPoolExecutor, as_completed, ThreadPoolExecutor
#########################################################################################################################
#########################################################################################################################
# Set working directory
os.chdir('C:\\Users\\Elkanah\\Desktop\\Elkanah\\Spatiotemporal_AR_Model_LASSO')
##########################################################################################################################
##########################################################################################################################
###################################################################################################################
########################################################################################################################
#Parameter initialization
num_replications = 100
Time = 200
n = 4
beta = np.array([3, 0, 2])
k = 3
phi = np.array([0] * int(n * 0.25) + [0.3] * (n - int(n * 0.25)))
rho = 0.6
#################### Load data
WM = pyreadr.read_r(f'WM{n}.rda')
# Convert WM to a NumPy array
WM = np.array(list(WM.values())).reshape((n, n))
A = np.linalg.inv(np.eye(n) - rho * WM)

parameters = np.concatenate((beta, phi, rho * WM[np.triu_indices(WM.shape[0], k=1)], rho * WM[np.tril_indices(WM.shape[0], k=-1)],[1], [np.nan,np.nan,np.nan,np.nan,np.nan]))
###################################################################################################################
#########################################################################################################################
# Define the Log-Likelihood function
def LL(parameters, Y, X, n, k, Time, lambda1, lambda2, lambda3):
    # Extract the parameters
    beta = parameters[:k]
    phi = parameters[k:k+n]
    W = np.zeros((n, n))
    W[np.triu_indices(n, k=1)] = parameters[int(k+n):int(k+n+0.5*n*(n-1))]
    W[np.tril_indices(n, k=-1)] = parameters[int(k+n+0.5*n*(n-1)):int(k+n+n*(n-1))]
    sigma2_eps = parameters[int(k+n+n*(n-1))]

    # Calculate sum of squares
    residuals_est = np.zeros(Time - 1)
    for t in range(1, Time):
        u_t = Y[:, t] - W @ Y[:, t] - X[:, t] @ beta - phi * Y[:, t-1]
        residuals_est[t-1] = np.sum(u_t**2 / sigma2_eps)

    sum_of_squares = np.sum(residuals_est)

    # Calculate log-likelihood
    Constant = -0.5 * (Time - 1) * (np.log(2 * np.pi) + np.sum(n * np.log(sigma2_eps))) + (Time - 1) * np.linalg.slogdet(np.eye(n) - W)[1]
    LogLik = Constant - (0.5 * sum_of_squares) - (lambda3 * np.sum(np.abs(W)) + lambda2 * np.sum(np.abs(phi)) + lambda1 * np.sum(np.abs(beta)))

    return -LogLik
##########################################################################################################################
##########################################################################################################################
# Constraint function for W
def constraint_func(param, n, k):
    W = np.zeros((n, n))
    W[np.triu_indices(n, k=1)] = param[int(k+n):int(k+n+0.5*n*(n-1))]
    W[np.tril_indices(n, k=-1)] = param[int(k+n+0.5*n*(n-1)):int(k+n+n*(n-1))]
    row_sums = np.sum(W, axis=1)
    return 1 - row_sums  # Constraint: row_sums <= 1

##########################################################################################################################
##########################################################################################################################
# Function to perform cross-validation for all lambda combinations
def cross_validate_lambda_combination(X, Y, n, k, Time, param, bounds, num_folds=5):
    lambda_values1 = np.concatenate(([0], np.logspace(-1, 0, 0)))
    lambda_values2 = np.concatenate(([0], np.logspace(-1, 0, 0)))
    lambda_values3 = np.concatenate(([0], np.logspace(-1, 0, 0)))

    # Create a list of lambda combinations
    lambda_combinations = np.array(list(itertools.product(lambda_values1, lambda_values2, lambda_values3)))

    Av_RMSE = np.zeros((len(lambda_values1), len(lambda_values2), len(lambda_values3)))  # Array to store average RMSE values for each lambda combination

    def cross_validate_lambda(lambdas):
        folds_rmse_list = []

        def optimize_fold(param, lambdas, Y_train, X_train, n, k, train_index, bounds):
            result = minimize(LL, param, args=(Y_train, X_train, n, k, train_index, lambdas[0], lambdas[1], lambdas[2]),
                              method='SLSQP', bounds=bounds, constraints={'type': 'ineq', 'fun': lambda x: constraint_func(x, n, k)})
            return result

        # Iterate over the folds
        with concurrent.futures.ThreadPoolExecutor() as fold_executor:
            fold_results = []

            for fold in range(num_folds):
                test_indices = np.arange(fold, Time, num_folds)
                train_indices = np.delete(np.arange(Time), test_indices)
                X_train = X[:, train_indices]
                Y_train = Y[:, train_indices]
                X_test = X[:, test_indices]
                Y_test = Y[:, test_indices]

                result = fold_executor.submit(optimize_fold, param, lambdas, Y_train, X_train, n, k, len(train_indices), bounds)
                fold_results.append(result)

            concurrent.futures.wait(fold_results)

            for result in fold_results:
                betas_opt = result.result().x[:k]
                phis_opt = result.result().x[k:k + n]
                W_opt = np.zeros((n, n))
                W_opt[np.triu_indices(n, k=1)] = result.result().x[int(k + n):int(k + n + 0.5 * n * (n - 1))]
                W_opt[np.tril_indices(n, k=-1)] = result.result().x[int(k + n + 0.5 * n * (n - 1)):int(k + n + n * (n - 1))]

                Y_pred = np.zeros((n, len(test_indices)))
                Aopt = np.linalg.inv(np.eye(n) - W_opt)
                for t in range(1, len(test_indices)):
                    if t == 1:
                        Y_pred[:, t] = np.dot(Aopt, (np.dot(X_test[:, t, :], betas_opt)))
                    else:
                        Y_pred[:, t] = np.dot(Aopt, (np.dot(X_test[:, t, :], betas_opt) + phis_opt * Y_pred[:, t-1]))

                rmse = np.sqrt(np.mean((Y_pred - Y_test) ** 2))
                folds_rmse_list.append(rmse)

        # Calculate the average RMSE from the list of fold RMSE values
        avg_rmse = np.mean(folds_rmse_list)
        return avg_rmse

    with concurrent.futures.ThreadPoolExecutor() as lambda_executor:
        # Create tasks for each lambda combination and submit them concurrently
        lambda_results = [
            lambda_executor.submit(cross_validate_lambda, lambdas)
            for lambdas in lambda_combinations
        ]

        concurrent.futures.wait(lambda_results)

        for i, lambdas in enumerate(lambda_combinations):
            lambda_result = lambda_results[i].result()
            lambda1, lambda2, lambda3 = lambdas
            ind_lambda1 = np.where(lambda_values1 == lambda1)[0][0]
            ind_lambda2 = np.where(lambda_values2 == lambda2)[0][0]
            ind_lambda3 = np.where(lambda_values3 == lambda3)[0][0]
            Av_RMSE[ind_lambda1, ind_lambda2, ind_lambda3] = lambda_result

    return Av_RMSE, lambda_combinations, lambda_values1, lambda_values2, lambda_values3
##########################################################################################################################
##########################################################################################################################
# Function for replication simulation
def replication_simulation(replication_id, Time):
    np.random.seed(replication_id)
    start_time = time.time()
    #print(f'Simulation {replication_id + 1} has started')
    Time = Time
    XVar = np.random.normal(0, 1, size=(n, Time + 100, k))
    eps = np.random.normal(size=(n, Time + 100))
    Yo = np.random.normal(0, 1, size=n)
    YVar = np.zeros((n, Time + 100))
    
    for t in range(1, Time + 100):
        if t == 1:
            YVar[:, t] = np.dot(A, (np.dot(XVar[:, t, :], beta) + phi * Yo + eps[:, t]))
        else:
            YVar[:, t] = np.dot(A, (np.dot(XVar[:, t, :], beta) + phi * YVar[:, t-1] + eps[:, t]))

    Y = YVar[:, 100:]
    X = XVar[:, 100:, :]
    param = np.concatenate((np.ones(k), np.repeat(0.1, n), np.repeat(0.001, int(n*(n-1))), [1]))
    bounds = [(-1, 5)] * k + [(0, 1)] * n + [(0, 1)] * int(n * (n - 1)) + [(0.0000000000001, np.inf)]

    #############################################################################################################
    # Calculate average RMSE values for lambda combinations
    Av_RMSE, lambda_combinations, lambda_values1, lambda_values2, lambda_values3 = cross_validate_lambda_combination(X, Y, n, k, Time, param, bounds)
    #print('The Average RMSE is \n', Av_RMSE)
    
    # Find the minimum average RMSE value and corresponding lambda combination
    min_avg_rmse = np.min(Av_RMSE)
    #best_lambda_combination = lambda_combinations[np.argmin(Av_RMSE)]
    #lambda1_opt, lambda2_opt, lambda3_opt = best_lambda_combination
    lambda1_opt, lambda2_opt, lambda3_opt = lambda_combinations[np.argmin(Av_RMSE)]
    ######################################################################################################
    result = minimize(LL, param, args=(Y, X, n, k, Time, lambda1_opt, lambda2_opt, lambda3_opt), method='SLSQP', bounds=bounds, constraints={'type': 'ineq', 'fun': lambda x: constraint_func(x, n, k)})
    parameters_opt = result.x

    betas_opt = parameters_opt[:k]
    phis_opt = parameters_opt[k:k+n]
    W_opt = np.zeros((n, n))
    W_opt[np.triu_indices(n, k=1)] = parameters_opt[int(k + n):int(k + n + 0.5 * n * (n - 1))]
    W_opt[np.tril_indices(n, k=-1)] = parameters_opt[int(k + n + 0.5 * n * (n - 1)):int(k + n + n * (n - 1))]

    Y_pred = np.zeros((n, Time))
    Aopt = np.linalg.inv(np.eye(n) - W_opt)
    for t in range(1, Time):
        if t == 1:
            Y_pred[:, t] = np.dot(Aopt, (np.dot(X[:, t, :], betas_opt)))
        else:
            Y_pred[:, t] = np.dot(Aopt, (np.dot(X[:, t, :], betas_opt) + phis_opt * Y_pred[:, t-1]))

    rmse_est = np.sqrt(np.mean((Y_pred - Y)**2))
    ##########################################################################################################################
    end_time = time.time()
    timetaken = end_time - start_time
    print(f'Replication {replication_id + 1} for {Time} timepoints ended in {timetaken} seconds with an RMSE of {rmse_est:4f} and penalties {lambda1_opt, lambda2_opt, lambda3_opt}')
    return np.concatenate((parameters_opt, [rmse_est, timetaken, lambda1_opt, lambda2_opt, lambda3_opt]))
##########################################################################################################################
##########################################################################################################################
if __name__ == "__main__":
    results_for_time = []  # Create a list to store results for the current time point
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(replication_simulation, i, Time) for i in range(num_replications)]

        for future in concurrent.futures.as_completed(futures):
            if future.result() is not None:
                results_for_time.append(future.result())  # Append results for the current time point
        np.save(f'RESULTS/Estimated_results_N={n}_{Time}_timepoints.npy', results_for_time)
# Out:
# C:\Users\Elkanah\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# Replication 6 for 200 timepoints ended in 17476.387380599976 seconds with an RMSE of 1.717248 and penalties (0.0, 0.0, 0.0)
# Replication 7 for 200 timepoints ended in 17490.38092136383 seconds with an RMSE of 1.866833 and penalties (0.0, 0.0, 0.0)
# Replication 5 for 200 timepoints ended in 17504.297954320908 seconds with an RMSE of 1.743154 and penalties (0.0, 0.0, 0.0)
# Replication 4 for 200 timepoints ended in 17508.89919424057 seconds with an RMSE of 1.821492 and penalties (0.0, 0.0, 0.0)
# Replication 8 for 200 timepoints ended in 17514.44795870781 seconds with an RMSE of 1.848686 and penalties (0.0, 0.0, 0.0)
# Replication 9 for 200 timepoints ended in 17522.600277900696 seconds with an RMSE of 1.546150 and penalties (0.0, 0.0, 0.0)
# Replication 16 for 200 timepoints ended in 17545.967616081238 seconds with an RMSE of 1.803681 and penalties (0.0, 0.0, 0.0)
# Replication 1 for 200 timepoints ended in 17548.27918601036 seconds with an RMSE of 1.822111 and penalties (0.0, 0.0, 0.0)
# Replication 13 for 200 timepoints ended in 25040.604965686798 seconds with an RMSE of 1.584063 and penalties (0.0, 0.0, 0.0)
# Replication 15 for 200 timepoints ended in 25047.69856452942 seconds with an RMSE of 1.756840 and penalties (0.0, 0.0, 0.0)
# Replication 12 for 200 timepoints ended in 25061.697095394135 seconds with an RMSE of 1.890277 and penalties (0.0, 0.0, 0.0)
# Replication 11 for 200 timepoints ended in 25067.495973587036 seconds with an RMSE of 1.791568 and penalties (0.0, 0.0, 0.0)
# Replication 10 for 200 timepoints ended in 25122.049978256226 seconds with an RMSE of 1.803955 and penalties (0.0, 0.0, 0.0)
# Replication 3 for 200 timepoints ended in 25129.519042015076 seconds with an RMSE of 1.886564 and penalties (0.0, 0.0, 0.0)
# Replication 2 for 200 timepoints ended in 25149.49070072174 seconds with an RMSE of 1.713562 and penalties (0.0, 0.0, 0.0)
# Replication 14 for 200 timepoints ended in 25171.24379324913 seconds with an RMSE of 1.886700 and penalties (0.0, 0.0, 0.0)
# Replication 20 for 200 timepoints ended in 8290.565184354782 seconds with an RMSE of 1.781191 and penalties (0.0, 0.0, 0.0)
# Replication 18 for 200 timepoints ended in 8326.235374689102 seconds with an RMSE of 2.228117 and penalties (0.0, 0.0, 0.0)
# Replication 17 for 200 timepoints ended in 8346.139182806015 seconds with an RMSE of 1.656517 and penalties (0.0, 0.0, 0.0)
# Replication 22 for 200 timepoints ended in 8336.485134363174 seconds with an RMSE of 1.811833 and penalties (0.0, 0.0, 0.0)
# Replication 28 for 200 timepoints ended in 791.851366519928 seconds with an RMSE of 1.597661 and penalties (0.0, 0.0, 0.0)
# Replication 19 for 200 timepoints ended in 8373.003055095673 seconds with an RMSE of 1.950348 and penalties (0.0, 0.0, 0.0)
# Replication 21 for 200 timepoints ended in 8371.058965682983 seconds with an RMSE of 1.756367 and penalties (0.0, 0.0, 0.0)
# Replication 23 for 200 timepoints ended in 8349.005624055862 seconds with an RMSE of 1.777748 and penalties (0.0, 0.0, 0.0)
# Replication 25 for 200 timepoints ended in 871.3029909133911 seconds with an RMSE of 1.636505 and penalties (0.0, 0.0, 0.0)
# Replication 24 for 200 timepoints ended in 8385.353365659714 seconds with an RMSE of 1.470120 and penalties (0.0, 0.0, 0.0)
# Replication 30 for 200 timepoints ended in 804.2891263961792 seconds with an RMSE of 1.731996 and penalties (0.0, 0.0, 0.0)
# Replication 26 for 200 timepoints ended in 893.5124661922455 seconds with an RMSE of 1.765584 and penalties (0.0, 0.0, 0.0)
# Replication 27 for 200 timepoints ended in 885.2595317363739 seconds with an RMSE of 1.573523 and penalties (0.0, 0.0, 0.0)
# Replication 32 for 200 timepoints ended in 784.3289060592651 seconds with an RMSE of 1.786527 and penalties (0.0, 0.0, 0.0)
# Replication 29 for 200 timepoints ended in 890.6669173240662 seconds with an RMSE of 1.520743 and penalties (0.0, 0.0, 0.0)
# Replication 31 for 200 timepoints ended in 913.8726997375488 seconds with an RMSE of 1.828317 and penalties (0.0, 0.0, 0.0)
# Replication 33 for 200 timepoints ended in 1650.4721310138702 seconds with an RMSE of 1.689669 and penalties (0.0, 0.0, 0.0)
# Replication 34 for 200 timepoints ended in 1646.5293962955475 seconds with an RMSE of 1.671321 and penalties (0.0, 0.0, 0.0)
# Replication 35 for 200 timepoints ended in 1642.327649116516 seconds with an RMSE of 1.775703 and penalties (0.0, 0.0, 0.0)
# Replication 38 for 200 timepoints ended in 1630.0208094120026 seconds with an RMSE of 1.956437 and penalties (0.0, 0.0, 0.0)
# Replication 40 for 200 timepoints ended in 1643.042091369629 seconds with an RMSE of 1.700624 and penalties (0.0, 0.0, 0.0)
# Replication 44 for 200 timepoints ended in 1615.755669593811 seconds with an RMSE of 1.945489 and penalties (0.0, 0.0, 0.0)
# Replication 36 for 200 timepoints ended in 1705.2194452285767 seconds with an RMSE of 1.886043 and penalties (0.0, 0.0, 0.0)
# Replication 37 for 200 timepoints ended in 1708.4950289726257 seconds with an RMSE of 1.714049 and penalties (0.0, 0.0, 0.0)
# Replication 39 for 200 timepoints ended in 1703.168616771698 seconds with an RMSE of 1.805128 and penalties (0.0, 0.0, 0.0)
# Replication 43 for 200 timepoints ended in 1658.0178225040436 seconds with an RMSE of 1.833614 and penalties (0.0, 0.0, 0.0)
# Replication 46 for 200 timepoints ended in 1636.8515889644623 seconds with an RMSE of 1.816726 and penalties (0.0, 0.0, 0.0)
# Replication 45 for 200 timepoints ended in 1657.4348788261414 seconds with an RMSE of 1.528201 and penalties (0.0, 0.0, 0.0)
# Replication 41 for 200 timepoints ended in 1714.6638858318329 seconds with an RMSE of 1.752037 and penalties (0.0, 0.0, 0.0)
# Replication 42 for 200 timepoints ended in 1700.4281980991364 seconds with an RMSE of 1.830995 and penalties (0.0, 0.0, 0.0)
# Replication 48 for 200 timepoints ended in 1574.122386455536 seconds with an RMSE of 1.712557 and penalties (0.0, 0.0, 0.0)
# Replication 47 for 200 timepoints ended in 1717.9928848743439 seconds with an RMSE of 1.732306 and penalties (0.0, 0.0, 0.0)
# Replication 51 for 200 timepoints ended in 772.4554119110107 seconds with an RMSE of 1.638925 and penalties (0.0, 0.0, 0.0)
# Replication 49 for 200 timepoints ended in 800.7669703960419 seconds with an RMSE of 1.985255 and penalties (0.0, 0.0, 0.0)
# Replication 50 for 200 timepoints ended in 794.6745629310608 seconds with an RMSE of 1.704539 and penalties (0.0, 0.0, 0.0)
# Replication 54 for 200 timepoints ended in 750.9326822757721 seconds with an RMSE of 1.748537 and penalties (0.0, 0.0, 0.0)
# Replication 52 for 200 timepoints ended in 802.9753890037537 seconds with an RMSE of 1.629817 and penalties (0.0, 0.0, 0.0)
# Replication 53 for 200 timepoints ended in 773.0619246959686 seconds with an RMSE of 1.816433 and penalties (0.0, 0.0, 0.0)
# Replication 57 for 200 timepoints ended in 739.138266324997 seconds with an RMSE of 1.797664 and penalties (0.0, 0.0, 0.0)
# Replication 56 for 200 timepoints ended in 773.2106699943542 seconds with an RMSE of 1.977978 and penalties (0.0, 0.0, 0.0)
# Replication 60 for 200 timepoints ended in 753.7748968601227 seconds with an RMSE of 1.957857 and penalties (0.0, 0.0, 0.0)
# Replication 58 for 200 timepoints ended in 768.7928755283356 seconds with an RMSE of 2.028623 and penalties (0.0, 0.0, 0.0)
# Replication 55 for 200 timepoints ended in 797.9008464813232 seconds with an RMSE of 1.577399 and penalties (0.0, 0.0, 0.0)
# Replication 61 for 200 timepoints ended in 751.9589898586273 seconds with an RMSE of 2.003583 and penalties (0.0, 0.0, 0.0)
# Replication 59 for 200 timepoints ended in 801.6693060398102 seconds with an RMSE of 1.871483 and penalties (0.0, 0.0, 0.0)
# Replication 63 for 200 timepoints ended in 766.7180259227753 seconds with an RMSE of 1.862152 and penalties (0.0, 0.0, 0.0)
# Replication 62 for 200 timepoints ended in 859.6560525894165 seconds with an RMSE of 1.980464 and penalties (0.0, 0.0, 0.0)
# Replication 64 for 200 timepoints ended in 1458.9716835021973 seconds with an RMSE of 2.053475 and penalties (0.0, 0.0, 0.0)
# Replication 66 for 200 timepoints ended in 1345.640103340149 seconds with an RMSE of 1.723030 and penalties (0.0, 0.0, 0.0)
# Replication 67 for 200 timepoints ended in 1349.1539335250854 seconds with an RMSE of 1.919864 and penalties (0.0, 0.0, 0.0)
# Replication 65 for 200 timepoints ended in 1382.288737297058 seconds with an RMSE of 1.776875 and penalties (0.0, 0.0, 0.0)
# Replication 69 for 200 timepoints ended in 1365.81574010849 seconds with an RMSE of 1.919698 and penalties (0.0, 0.0, 0.0)
# Replication 68 for 200 timepoints ended in 3555.7692477703094 seconds with an RMSE of 1.641142 and penalties (0.0, 0.0, 0.0)
# Replication 70 for 200 timepoints ended in 3559.1426203250885 seconds with an RMSE of 1.580351 and penalties (0.0, 0.0, 0.0)
# Replication 71 for 200 timepoints ended in 3573.1904413700104 seconds with an RMSE of 2.042583 and penalties (0.0, 0.0, 0.0)
# Replication 73 for 200 timepoints ended in 3547.937094449997 seconds with an RMSE of 2.508576 and penalties (0.0, 0.0, 0.0)
# Replication 74 for 200 timepoints ended in 3547.013456106186 seconds with an RMSE of 1.795858 and penalties (0.0, 0.0, 0.0)
# Replication 78 for 200 timepoints ended in 3503.543808698654 seconds with an RMSE of 1.689754 and penalties (0.0, 0.0, 0.0)
# Replication 75 for 200 timepoints ended in 3553.116297721863 seconds with an RMSE of 1.759146 and penalties (0.0, 0.0, 0.0)
# Replication 77 for 200 timepoints ended in 3545.561240196228 seconds with an RMSE of 2.173627 and penalties (0.0, 0.0, 0.0)
# Replication 76 for 200 timepoints ended in 3561.3452689647675 seconds with an RMSE of 1.852796 and penalties (0.0, 0.0, 0.0)
# Replication 72 for 200 timepoints ended in 3627.360504388809 seconds with an RMSE of 1.689493 and penalties (0.0, 0.0, 0.0)
# Replication 79 for 200 timepoints ended in 3500.0720076560974 seconds with an RMSE of 1.747304 and penalties (0.0, 0.0, 0.0)
# Replication 80 for 200 timepoints ended in 2839.1471705436707 seconds with an RMSE of 1.810316 and penalties (0.0, 0.0, 0.0)
# Replication 81 for 200 timepoints ended in 2534.740305185318 seconds with an RMSE of 1.748645 and penalties (0.0, 0.0, 0.0)
# Replication 83 for 200 timepoints ended in 2518.5821166038513 seconds with an RMSE of 1.778394 and penalties (0.0, 0.0, 0.0)
# Replication 82 for 200 timepoints ended in 2536.1720068454742 seconds with an RMSE of 1.800445 and penalties (0.0, 0.0, 0.0)
# Replication 84 for 200 timepoints ended in 2503.2798833847046 seconds with an RMSE of 1.998510 and penalties (0.0, 0.0, 0.0)
# Replication 86 for 200 timepoints ended in 2485.005999326706 seconds with an RMSE of 1.787865 and penalties (0.0, 0.0, 0.0)
# Replication 85 for 200 timepoints ended in 2503.5748171806335 seconds with an RMSE of 1.675655 and penalties (0.0, 0.0, 0.0)
# Replication 89 for 200 timepoints ended in 2462.2293548583984 seconds with an RMSE of 1.649429 and penalties (0.0, 0.0, 0.0)
# Replication 87 for 200 timepoints ended in 2488.08860206604 seconds with an RMSE of 1.527885 and penalties (0.0, 0.0, 0.0)
# Replication 88 for 200 timepoints ended in 2488.546677350998 seconds with an RMSE of 1.760741 and penalties (0.0, 0.0, 0.0)
# Replication 92 for 200 timepoints ended in 2461.889506816864 seconds with an RMSE of 1.814073 and penalties (0.0, 0.0, 0.0)
# Replication 90 for 200 timepoints ended in 2497.8301010131836 seconds with an RMSE of 1.924885 and penalties (0.0, 0.0, 0.0)
# Replication 93 for 200 timepoints ended in 2471.5348875522614 seconds with an RMSE of 1.711335 and penalties (0.0, 0.0, 0.0)
# Replication 91 for 200 timepoints ended in 2510.6662607192993 seconds with an RMSE of 1.650954 and penalties (0.0, 0.0, 0.0)
# Replication 94 for 200 timepoints ended in 2475.7413854599 seconds with an RMSE of 1.729728 and penalties (0.0, 0.0, 0.0)
# Replication 95 for 200 timepoints ended in 2466.9096024036407 seconds with an RMSE of 1.686920 and penalties (0.0, 0.0, 0.0)
# Replication 96 for 200 timepoints ended in 2443.955857515335 seconds with an RMSE of 1.710619 and penalties (0.0, 0.0, 0.0)
# Replication 97 for 200 timepoints ended in 2357.304209470749 seconds with an RMSE of 1.788633 and penalties (0.0, 0.0, 0.0)
# Replication 99 for 200 timepoints ended in 2347.6577200889587 seconds with an RMSE of 1.759021 and penalties (0.0, 0.0, 0.0)
# Replication 100 for 200 timepoints ended in 2312.242043733597 seconds with an RMSE of 1.745982 and penalties (0.0, 0.0, 0.0)
# Replication 98 for 200 timepoints ended in 2355.917508840561 seconds with an RMSE of 1.741807 and penalties (0.0, 0.0, 0.0)
